# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_csv('data.csv', header=1)

# %%
X = data.iloc[:,:2]
y = data.iloc[:,-1]

# %%
X = np.array(X)
y = np.array(y)

# %%
# create a neural network class inheriting from the nn.Module
# Call it NeuralNetwork and make, and use "pass" in the constructor
# so that it doesn't give an error
# Instantiate one instance of it in variable net
class NeuralNetwork(nn.Module):
    def __init__(self):
        super(NeuralNetwork, self).__init__()
        pass
    
net = NeuralNetwork()

# %%
assert isinstance(net, NeuralNetwork)

# %%
# Rewrite the NeuralNetwork class so that the constructor receives
# as input the input_dim and num_hidden, respectively the dimension of 
# the input and the number of hidden neurons
# use pass again
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, num_hidden):
        super(NeuralNetwork, self).__init__()
        pass

# %%
assert NeuralNetwork(input_dim=10, num_hidden=16)

# %%
# Rewrite the NeuralNetwork class so that the constructor receives
# as input the input_dim, num_hidden1 and num_hidden2, respectively the dimension of 
# the input and the number of hidden neurons for the first fully connected
# layer and the second. Define the attributes in the constructor
# that consists of the layers, call them fc1, fc2 and fc3 and a sigmoid.
# use pass again. Be careful to put the dimensions in the right places!
# Since we will do a binary classification problem, fc3 will have 1 neuron
# as output
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, num_hidden1, num_hidden2):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, num_hidden1)
        self.fc2 = nn.Linear(num_hidden1, num_hidden2)
        self.fc3 = nn.Linear(num_hidden2, 1)
        self.sigmoid = nn.Sigmoid()

# %%
net = NeuralNetwork(16, 16, 16)
assert net.fc1
assert net.fc2
assert net.fc3
assert net.sigmoid

# %%
# Define the forward pass to make a reasonable use of the attributes
# you defined before. Follow the same reasoning we used in class
class NeuralNetwork(nn.Module):
    def __init__(self, input_dim, num_hidden1, num_hidden2):
        super().__init__()
        self.fc1 = nn.Linear(input_dim, num_hidden1)
        self.sigmoid = nn.Sigmoid()
        self.fc2 = nn.Linear(num_hidden1, num_hidden2)
        self.sigmoid = nn.Sigmoid()
        self.fc3 = nn.Linear(num_hidden2, 1)
        
    def forward(self, x):
        l1 = self.fc1(x)
        activation = self.sigmoid(l1)
        l2 = self.fc2(activation)
        activation = self.sigmoid(l2)
        l3 = self.fc3(activation)
        output = self.sigmoid(l3)
        return output

# %%
# For training a model, use the following optimizer and loss
loss = nn.BCELoss()
model = NeuralNetwork(2, 3, 3)
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
x_tensor = torch.tensor(X).float()
y_true_sensor = torch.tensor(y).float()
y_true_sensor = y_true_sensor.reshape(X.shape[0], 1)
y_pred_tensor = model(x_tensor)
loss_value = loss(y_pred_tensor, y_true_sensor)
print(f"Initial loss: {loss_value.item():.2f}")
# Out:
# Initial loss: 0.69

# %%
# train a neural network (feel free to choose the num_hidden1 and num_hidden2)
# on the dataset in data.csv file
# You'll have fun with conflicting shapes and types and tensors, but
# you'll get those errors anyway. Let's go into the wild and learn
# by reading the errors and trying to understand them! :)
# You can always use the provided Workbook
def torch_fit(X, y, model, loss, lr, num_epochs):
    loss_list = []
    optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
    for epoch in range(num_epochs):
        optimizer.zero_grad()
        y_pred_tensor = model(X)
        loss_value = loss(y_pred_tensor, y_true_sensor)
        print(f'Epoch {epoch}, loss {loss_value.item():.2f}')
        loss_value.backward()
        optimizer.step()
    return model

model = torch_fit(x_tensor, y_true_sensor, model=model, loss=loss, lr=0.01, num_epochs=300)
# Out:
# Epoch 0, loss 0.52
# Epoch 1, loss 0.52
# Epoch 2, loss 0.52
# Epoch 3, loss 0.51
# Epoch 4, loss 0.51
# Epoch 5, loss 0.51
# Epoch 6, loss 0.50
# Epoch 7, loss 0.50
# Epoch 8, loss 0.50
# Epoch 9, loss 0.49
# Epoch 10, loss 0.49
# Epoch 11, loss 0.49
# Epoch 12, loss 0.48
# Epoch 13, loss 0.48
# Epoch 14, loss 0.48
# Epoch 15, loss 0.47
# Epoch 16, loss 0.47
# Epoch 17, loss 0.47
# Epoch 18, loss 0.46
# Epoch 19, loss 0.46
# Epoch 20, loss 0.46
# Epoch 21, loss 0.45
# Epoch 22, loss 0.45
# Epoch 23, loss 0.45
# Epoch 24, loss 0.44
# Epoch 25, loss 0.44
# Epoch 26, loss 0.44
# Epoch 27, loss 0.43
# Epoch 28, loss 0.43
# Epoch 29, loss 0.43
# Epoch 30, loss 0.42
# Epoch 31, loss 0.42
# Epoch 32, loss 0.42
# Epoch 33, loss 0.41
# Epoch 34, loss 0.41
# Epoch 35, loss 0.41
# Epoch 36, loss 0.40
# Epoch 37, loss 0.40
# Epoch 38, loss 0.40
# Epoch 39, loss 0.39
# Epoch 40, loss 0.39
# Epoch 41, loss 0.39
# Epoch 42, loss 0.38
# Epoch 43, loss 0.38
# Epoch 44, loss 0.38
# Epoch 45, loss 0.37
# Epoch 46, loss 0.37
# Epoch 47, loss 0.37
# Epoch 48, loss 0.36
# Epoch 49, loss 0.36
# Epoch 50, loss 0.36
# Epoch 51, loss 0.36
# Epoch 52, loss 0.35
# Epoch 53, loss 0.35
# Epoch 54, loss 0.35
# Epoch 55, loss 0.34
# Epoch 56, loss 0.34
# Epoch 57, loss 0.34
# Epoch 58, loss 0.33
# Epoch 59, loss 0.33
# Epoch 60, loss 0.33
# Epoch 61, loss 0.33
# Epoch 62, loss 0.32
# Epoch 63, loss 0.32
# Epoch 64, loss 0.32
# Epoch 65, loss 0.32
# Epoch 66, loss 0.31
# Epoch 67, loss 0.31
# Epoch 68, loss 0.31
# Epoch 69, loss 0.30
# Epoch 70, loss 0.30
# Epoch 71, loss 0.30
# Epoch 72, loss 0.30
# Epoch 73, loss 0.29
# Epoch 74, loss 0.29
# Epoch 75, loss 0.29
# Epoch 76, loss 0.29
# Epoch 77, loss 0.29
# Epoch 78, loss 0.28
# Epoch 79, loss 0.28
# Epoch 80, loss 0.28
# Epoch 81, loss 0.28
# Epoch 82, loss 0.27
# Epoch 83, loss 0.27
# Epoch 84, loss 0.27
# Epoch 85, loss 0.27
# Epoch 86, loss 0.27
# Epoch 87, loss 0.26
# Epoch 88, loss 0.26
# Epoch 89, loss 0.26
# Epoch 90, loss 0.26
# Epoch 91, loss 0.26
# Epoch 92, loss 0.25
# Epoch 93, loss 0.25
# Epoch 94, loss 0.25
# Epoch 95, loss 0.25
# Epoch 96, loss 0.25
# Epoch 97, loss 0.25
# Epoch 98, loss 0.24
# Epoch 99, loss 0.24
# Epoch 100, loss 0.24
# Epoch 101, loss 0.24
# Epoch 102, loss 0.24
# Epoch 103, loss 0.24
# Epoch 104, loss 0.23
# Epoch 105, loss 0.23
# Epoch 106, loss 0.23
# Epoch 107, loss 0.23
# Epoch 108, loss 0.23
# Epoch 109, loss 0.23
# Epoch 110, loss 0.23
# Epoch 111, loss 0.22
# Epoch 112, loss 0.22
# Epoch 113, loss 0.22
# Epoch 114, loss 0.22
# Epoch 115, loss 0.22
# Epoch 116, loss 0.22
# Epoch 117, loss 0.22
# Epoch 118, loss 0.22
# Epoch 119, loss 0.21
# Epoch 120, loss 0.21
# Epoch 121, loss 0.21
# Epoch 122, loss 0.21
# Epoch 123, loss 0.21
# Epoch 124, loss 0.21
# Epoch 125, loss 0.21
# Epoch 126, loss 0.21
# Epoch 127, loss 0.21
# Epoch 128, loss 0.20
# Epoch 129, loss 0.20
# Epoch 130, loss 0.20
# Epoch 131, loss 0.20
# Epoch 132, loss 0.20
# Epoch 133, loss 0.20
# Epoch 134, loss 0.20
# Epoch 135, loss 0.20
# Epoch 136, loss 0.20
# Epoch 137, loss 0.20
# Epoch 138, loss 0.20
# Epoch 139, loss 0.19
# Epoch 140, loss 0.19
# Epoch 141, loss 0.19
# Epoch 142, loss 0.19
# Epoch 143, loss 0.19
# Epoch 144, loss 0.19
# Epoch 145, loss 0.19
# Epoch 146, loss 0.19
# Epoch 147, loss 0.19
# Epoch 148, loss 0.19
# Epoch 149, loss 0.19
# Epoch 150, loss 0.19
# Epoch 151, loss 0.19
# Epoch 152, loss 0.19
# Epoch 153, loss 0.18
# Epoch 154, loss 0.18
# Epoch 155, loss 0.18
# Epoch 156, loss 0.18
# Epoch 157, loss 0.18
# Epoch 158, loss 0.18
# Epoch 159, loss 0.18
# Epoch 160, loss 0.18
# Epoch 161, loss 0.18
# Epoch 162, loss 0.18
# Epoch 163, loss 0.18
# Epoch 164, loss 0.18
# Epoch 165, loss 0.18
# Epoch 166, loss 0.18
# Epoch 167, loss 0.18
# Epoch 168, loss 0.18
# Epoch 169, loss 0.18
# Epoch 170, loss 0.18
# Epoch 171, loss 0.18
# Epoch 172, loss 0.17
# Epoch 173, loss 0.17
# Epoch 174, loss 0.17
# Epoch 175, loss 0.17
# Epoch 176, loss 0.17
# Epoch 177, loss 0.17
# Epoch 178, loss 0.17
# Epoch 179, loss 0.17
# Epoch 180, loss 0.17
# Epoch 181, loss 0.17
# Epoch 182, loss 0.17
# Epoch 183, loss 0.17
# Epoch 184, loss 0.17
# Epoch 185, loss 0.17
# Epoch 186, loss 0.17
# Epoch 187, loss 0.17
# Epoch 188, loss 0.17
# Epoch 189, loss 0.17
# Epoch 190, loss 0.17
# Epoch 191, loss 0.17
# Epoch 192, loss 0.17
# Epoch 193, loss 0.17
# Epoch 194, loss 0.17
# Epoch 195, loss 0.17
# Epoch 196, loss 0.17
# Epoch 197, loss 0.17
# Epoch 198, loss 0.17
# Epoch 199, loss 0.17
# Epoch 200, loss 0.16
# Epoch 201, loss 0.16
# Epoch 202, loss 0.16
# Epoch 203, loss 0.16
# Epoch 204, loss 0.16
# Epoch 205, loss 0.16
# Epoch 206, loss 0.16
# Epoch 207, loss 0.16
# Epoch 208, loss 0.16
# Epoch 209, loss 0.16
# Epoch 210, loss 0.16
# Epoch 211, loss 0.16
# Epoch 212, loss 0.16
# Epoch 213, loss 0.16
# Epoch 214, loss 0.16
# Epoch 215, loss 0.16
# Epoch 216, loss 0.16
# Epoch 217, loss 0.16
# Epoch 218, loss 0.16
# Epoch 219, loss 0.16
# Epoch 220, loss 0.16
# Epoch 221, loss 0.16
# Epoch 222, loss 0.16
# Epoch 223, loss 0.16
# Epoch 224, loss 0.16
# Epoch 225, loss 0.16
# Epoch 226, loss 0.16
# Epoch 227, loss 0.16
# Epoch 228, loss 0.16
# Epoch 229, loss 0.16
# Epoch 230, loss 0.16
# Epoch 231, loss 0.16
# Epoch 232, loss 0.16
# Epoch 233, loss 0.16
# Epoch 234, loss 0.16
# Epoch 235, loss 0.16
# Epoch 236, loss 0.16
# Epoch 237, loss 0.16
# Epoch 238, loss 0.16
# Epoch 239, loss 0.16
# Epoch 240, loss 0.16
# Epoch 241, loss 0.16
# Epoch 242, loss 0.16
# Epoch 243, loss 0.16
# Epoch 244, loss 0.16
# Epoch 245, loss 0.16
# Epoch 246, loss 0.16
# Epoch 247, loss 0.16
# Epoch 248, loss 0.16
# Epoch 249, loss 0.16
# Epoch 250, loss 0.16
# Epoch 251, loss 0.16
# Epoch 252, loss 0.16
# Epoch 253, loss 0.16
# Epoch 254, loss 0.16
# Epoch 255, loss 0.16
# Epoch 256, loss 0.16
# Epoch 257, loss 0.15
# Epoch 258, loss 0.15
# Epoch 259, loss 0.15
# Epoch 260, loss 0.15
# Epoch 261, loss 0.15
# Epoch 262, loss 0.15
# Epoch 263, loss 0.15
# Epoch 264, loss 0.15
# Epoch 265, loss 0.15
# Epoch 266, loss 0.15
# Epoch 267, loss 0.15
# Epoch 268, loss 0.15
# Epoch 269, loss 0.15
# Epoch 270, loss 0.15
# Epoch 271, loss 0.15
# Epoch 272, loss 0.15
# Epoch 273, loss 0.15
# Epoch 274, loss 0.15
# Epoch 275, loss 0.15
# Epoch 276, loss 0.15
# Epoch 277, loss 0.15
# Epoch 278, loss 0.15
# Epoch 279, loss 0.15
# Epoch 280, loss 0.15
# Epoch 281, loss 0.15
# Epoch 282, loss 0.15
# Epoch 283, loss 0.15
# Epoch 284, loss 0.15
# Epoch 285, loss 0.15
# Epoch 286, loss 0.15
# Epoch 287, loss 0.15
# Epoch 288, loss 0.15
# Epoch 289, loss 0.15
# Epoch 290, loss 0.15
# Epoch 291, loss 0.15
# Epoch 292, loss 0.15
# Epoch 293, loss 0.15
# Epoch 294, loss 0.15
# Epoch 295, loss 0.15
# Epoch 296, loss 0.15
# Epoch 297, loss 0.15
# Epoch 298, loss 0.15
# Epoch 299, loss 0.15
