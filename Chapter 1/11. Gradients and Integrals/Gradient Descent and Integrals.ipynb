# %%
import numpy as np
import matplotlib.pyplot as plt
#!pip3 install --upgrade
#!pip3 install sympy

# %%
from scipy.misc import derivative

# %%
def function(x):
    return 10*np.sin(x) - np.sin(1/x) + 5*np.cos(2*x) + 1/2*np.sin(np.exp(x)) + x

# %%
x = np.linspace(-7,5,10000)
X, Y = x, function(x)

# %%
x = np.linspace(-7,5,10000)

# %%
plt.plot(X, Y)

# %% [markdown]
# The following algorithm is supposed to iteratively find the minimum of a function.
#
# What problem does it have?

# %%
import matplotlib.cm as cm
x = X
index = np.random.randint(0, len(x)) # randomly select an index to sample a point
point = x[index] # sample a point to start
derivative_in_point = derivative(function, point)
it = 0 # current iteration
max_it = 100 # set the max number of iterations to avoid infinite loops
points = [] # list of the points we have inspected
threshold = 0.01 # instead for waiting till we reach the 0 of the derivative, put a threshold
while np.abs(derivative_in_point)> 0.01 and it<max_it: 
    if derivative_in_point < 0: # the slope is negative
        x = x[index:] # since the slope is negative, the local minimum should be on the right
        index = np.random.randint(0, len(x)) # randomly select an index
        point = x[index] # sample the next point in the new interval
        points.append(point) # store for later
        derivative_in_point = derivative(function, point) # compute the derivative in the new point
    else:
        x = x[0:index+1] # the slope is positive, so the minimum should be on the left
        index = np.random.randint(0, len(x))
        point = x[index]
        points.append(point)
        derivative_in_point = derivative(function, point)
    it +=1
    plt.figure()
    plt.plot(X,Y)
    plt.scatter(np.array(points), function(np.array(points)), c=range(len(points)), cmap=cm.jet)
    plt.title(str(it))
    plt.colorbar()

# %% [markdown]
# ## Exercise
#
# 1. Can you make the algorithm above to be implemented into a fuction `gradient_descent(function, X, max_it)`?
#
# 2. Run the experiment multiple times: do you notice any important difference at each iteration?

# %%
import matplotlib.cm as cm

def gradient_descent(function, Xlin, max_it):
    X_int, Y = Xlin, function(Xlin)
    x = X_int
    index = np.random.randint(0, len(x)) # randomly select an index to sample a point
    point = x[index] # sample a point to start
    derivative_in_point = derivative(function, point)
    it = 0 # current iteration
    #print(max_it)
    # max_it = 100 # set the max number of iterations to avoid infinite loops
    points = [] # list of the points we have inspected
    threshold = 0.01 # instead for waiting till we reach the 0 of the derivative, put a threshold
    while np.abs(derivative_in_point)> 0.01 and it<max_it: 
        if derivative_in_point < 0: # the slope is negative
            x = x[index:] # since the slope is negative, the local minimum should be on the right
            index = np.random.randint(0, len(x)) # randomly select an index
            point = x[index] # sample the next point in the new interval
            points.append(point) # store for later
            derivative_in_point = derivative(function, point) # compute the derivative in the new point
        else:
            x = x[0:index+1] # the slope is positive, so the minimum should be on the left
            index = np.random.randint(0, len(x))
            point = x[index]
            points.append(point)
            derivative_in_point = derivative(function, point)
            #print(derivative_in_point, point)
        #print(points)
        it +=1
        print("Total Number of Iterations:",it,"and Max Iterations:", max_it)
        plt.figure()
        plt.plot(X,Y)
        plt.scatter(np.array(points), function(np.array(points)), c=range(len(points)), cmap=cm.jet)
        plt.title(str(it))
        plt.colorbar()
        print("Derivative in Point:", derivative_in_point)
        
def function(x):
    return 10*np.sin(x) - np.sin(1/x) + 5*np.cos(2*x) + 1/2*np.sin(np.exp(x)) + x
   # return x**2
    
gradient_descent(function, np.linspace(-7,5,10000), 20)
#gradient_descent(function, np.linspace(-5,5,100), 10)
# Out:
# Total Number of Iterations: 1 and Max Iterations: 20
# Derivative in Point: 11.33008290940985
# Total Number of Iterations: 2 and Max Iterations: 20
# Derivative in Point: 11.019117146908913
# Total Number of Iterations: 3 and Max Iterations: 20
# Derivative in Point: 3.7818400193678694
# Total Number of Iterations: 4 and Max Iterations: 20
# Derivative in Point: 10.500686726808532
# Total Number of Iterations: 5 and Max Iterations: 20
# Derivative in Point: 12.192258666668042
# Total Number of Iterations: 6 and Max Iterations: 20
# Derivative in Point: 12.232287054399062
# Total Number of Iterations: 7 and Max Iterations: 20
# Derivative in Point: 12.011603831541814
# Total Number of Iterations: 8 and Max Iterations: 20
# Derivative in Point: 11.94210664815678
# Total Number of Iterations: 9 and Max Iterations: 20
# Derivative in Point: 11.928076539071947
# Total Number of Iterations: 10 and Max Iterations: 20
# Derivative in Point: 11.889119383525037
# Total Number of Iterations: 11 and Max Iterations: 20
# Derivative in Point: 11.889119383525037
# Total Number of Iterations: 12 and Max Iterations: 20
# Derivative in Point: 11.873931599455846
# Total Number of Iterations: 13 and Max Iterations: 20
# Derivative in Point: 11.873931599455846
# Total Number of Iterations: 14 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# Total Number of Iterations: 15 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# Total Number of Iterations: 16 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# Total Number of Iterations: 17 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# Total Number of Iterations: 18 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# Total Number of Iterations: 19 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# Total Number of Iterations: 20 and Max Iterations: 20
# Derivative in Point: 11.868798843159507
# takes the function, select the interval Xlin with the maximum iterations of max_it

# %%
print(len(points))

# %%
def function(x):
    #return 10*np.sin(x) - np.sin(1/x) + 5*np.cos(2*x) + 1/2*np.sin(np.exp(x)) + x
    return x**2

x = np.linspace(-7,5,1000)
X, Y = x, function(x)

# %% [markdown]
# ## Integral
#
# Scipy library also offers the possibility to compute the integral of a function.
#
# In addition, the method `plt.fill_between(section, function(section)` colors the area under the curve of a generic function.
#
# Search the documentation of both and compute the area under the curve of the functions in the given intervals of the following exercises and plot them.

# %% [markdown]
# ### Example
#
# interval = \[2,5\]
#
# Function f(x) = x

# %%
from scipy import integrate
a, b = [2, 5]
def f(x):
    return x

result = integrate.quad(f, a, b)
result
# Out:
# (10.5, 1.1657341758564144e-13)

# %% [markdown]
# The return value is a tuple, with the first element holding the estimated value of the integral and the second element holding an upper bound on the error.
#
# More in https://docs.scipy.org/doc/scipy/reference/tutorial/integrate.html .

# %%
area_under_the_curve = result[0]
area_under_the_curve

# %%
x = np.linspace(1,10, 100)
section = np.arange(2, 5, 1/20)
plt.plot(x, f(x))
plt.fill_between(section,f(section))

# %% [markdown]
# 1. interval = \[2,5\]
#
# Function f(x) = 5
#
# Compare the result computing the area by hand. Does it make sense?
#
# Be careful: defining a constant function, you may end up with a single number instead of an array of the same size of the input. For this, I recommend to put in your function `constant_value*np.ones_like(x)`.

# %%
from scipy import integrate

lower, upper = [2,5]
def f(x):
    return 5*np.ones_like(x)

result = integrate.quad(f, lower, upper)
result

area_under_the_curve = result[0]
x = np.linspace(1,7, 100)
section = np.arange(2, 5, 1/20)
plt.plot(x, f(x))
plt.fill_between(section,f(section))

# %% [markdown]
# 2. interval = \[-1,1\]
#
# Function f(x) = 1/x

# %%
import math
lower, upper = [-1,1]
def f(x):
    return np.divide(1, (x + (math.e)**3))

result = integrate.quad(f, lower, upper)
print(result)
area_under_the_curve = result[0]
x = np.linspace(-4,4, 100)
section = np.arange(-1, 1, 1/20)
plt.plot(x, f(x))
plt.fill_between(section,f(section))
# Out:
# (0.09965653251644367, 1.1064097695406136e-15)

# %%
from sympy import symbols, integrate
x = symbols('x')
f = integrate(1/(1-x**2), x)
result = (f.subs(x, 2) - f.subs(x, -2)).evalf()

# %% [markdown]
# 2. interval = \[-pi,pi\]
#
# Function f(x) = sin(x)

# %%
lower, upper = [-np.pi, np.pi]
def f(x):
    return np.sin(x)

result = integrate.quad(f, lower, upper)
result

area_under_the_curve = result[0]
x = np.linspace(-4,4, 100)
section = np.arange(-np.pi, np.pi, 1/20)
plt.plot(x, f(x))
plt.fill_between(section,f(section))

# %% [markdown]
# 3. interval = \[-pi,pi\]
#
# Function f(x) = cos(x)

# %%
lower, upper = [-np.pi, np.pi]
def f(x):
    return np.cos(x)

result = integrate.quad(f, lower, upper)
result

area_under_the_curve = result[0]
x = np.linspace(-4, 4, 100)
section = np.arange(-np.pi, np.pi, 1/20)
plt.plot(x, f(x))
plt.fill_between(section,f(section))

# %% [markdown]
# 2. interval = \[-pi,pi\]
#
# Function f(x) = sin(x) - cos(2x)

# %%
lower, upper = [-np.pi, np.pi]
def f(x):
    return np.sin(x) - np.cos(2*x)

result = integrate.quad(f, lower, upper)
result

area_under_the_curve = result[0]
x = np.linspace(-4, 4, 100)
section = np.arange(-np.pi, np.pi, 1/20)
plt.plot(x, f(x))
plt.fill_between(section,f(section))
